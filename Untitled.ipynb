# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import cv2
from imblearn.combine import SMOTETomek
from collections import Counter
from sklearn.datasets import make_classification
from torchvision import transforms
from imblearn.over_sampling import SMOTE
import seaborn as sns
import warnings
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import keras
import tensorflow as tf

warnings.filterwarnings('ignore')

path = r"C:\Users\Admin\.cache\kagglehub\datasets\msambare\fer2013\versions\1"

train_path = os.path.join(path, "train")
test_path = os.path.join(path, "test")

# %%
classes = os.listdir(train_path)
print(classes)
# Out:
# ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %%
train_dataset_path = r"C:\Users\Admin\.cache\kagglehub\datasets\msambare\fer2013\versions\1\train"

angry_path = r"C:\Users\Admin\.cache\kagglehub\datasets\msambare\fer2013\versions\1\train\angry"
disgust_path = r"C:\Users\Admin\.cache\kagglehub\datasets\msambare\fer2013\versions\1\train\disgust"
fear_path = r"C:\Users\Admin\.cache\kagglehub\datasets\msambare\fer2013\versions\1\train\fear"
happy_path = r"C:\Users\Admin\.cache\kagglehub\datasets\msambare\fer2013\versions\1\train\happy"
neutral_path = r"C:\Users\Admin\.cache\kagglehub\datasets\msambare\fer2013\versions\1\train\neutral"
sad_path = r"C:\Users\Admin\.cache\kagglehub\datasets\msambare\fer2013\versions\1\train\sad"
surprise_path = r"C:\Users\Admin\.cache\kagglehub\datasets\msambare\fer2013\versions\1\train\surprise"


angry_arr = os.listdir(angry_path)
disgust_arr = os.listdir(disgust_path)
fear_arr = os.listdir(fear_path)
happy_arr = os.listdir(happy_path)
neutral_arr = os.listdir(neutral_path)
sad_arr = os.listdir(sad_path)
surprise_arr = os.listdir(surprise_path)

train_dataset = angry_arr + disgust_arr + fear_arr + happy_arr + neutral_arr + sad_arr + surprise_arr

print("Angry: " + str(len(angry_arr)))
print("Disgust: " + str(len(disgust_arr)))
print("Fear: " + str(len(fear_arr)))
print("Happy: " + str(len(happy_arr)))
print("Neutral: " + str(len(neutral_arr)))
print("Sad: " + str(len(sad_arr)))
print("Surprise: " + str(len(surprise_arr)))
# Out:
# Angry: 3995
# Disgust: 436
# Fear: 4097
# Happy: 7215
# Neutral: 4965
# Sad: 4830
# Surprise: 3171

# %%
try:
    plt.imshow(Image.open(os.path.join(sad_path, sad_arr[16])))
    plt.axis('off') 
    plt.show()
except Exception as e:
    print(f"An error occurred: {e}")

# %%
image = cv2.imread('surprise.jpg')
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow('Grayscale', gray_image)

# %%
train_dataset = datasets.ImageFolder(train_dir, transform=train_transform)
path = r"C:\Users\Admin\.cache\kagglehub\datasets\msambare\fer2013\versions\1\train"

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  path,           
  seed=123,
  image_size=(224, 224),
  batch_size=32
)

for data, labels in train_ds:
  label = labels

sm = SMOTE(random_state=42)
train_smote,train_labels = sm.fit_resample(train_ds,label)
# Out:
# Found 28709 files belonging to 7 classes.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 15
#      12   label = labels
#      14 sm = SMOTE(random_state=42)
# ---> 15 train_smote,train_labels = sm.fit_resample(train_ds,label)
#
# File ~\anaconda3\envs\Emotions\Lib\site-packages\imblearn\base.py:204, in BaseSampler.fit_resample(self, X, y, **params)
#     183 def fit_resample(self, X, y, **params):
#     184     """Resample the dataset.
#     185
#     186     Parameters
#    (...)    202         The corresponding label of `X_resampled`.
#     203     """
# --> 204     return super().fit_resample(X, y, **params)
#
# File ~\anaconda3\envs\Emotions\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
# ...

# %%
img_path = "D:\\emotions\\msambare\\fer2013\\versions\\1\\train\\angry\\Training_3908.jpg"
img = Image.open(img_path)


single_transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=3),
  
])


transformed_img = single_transform(img)

# 4. Show the result
transformed_img.show()
