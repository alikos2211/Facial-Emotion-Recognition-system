# %%
import torch
import torch.nn as nn
from sklearn.utils.class_weight import compute_class_weight
import numpy as np
from torchvision.models import vit_b_16, ViT_B_16_Weights

device = "cuda" if torch.cuda.is_available() else "cpu"


#weights = ViT_B_16_Weights.DEFAULT if pretrained else None
model = vit_b_16()

# %%
model.layers()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model.layers()
#
# File ~\anaconda3\envs\Emotions\Lib\site-packages\torch\nn\modules\module.py:1965, in Module.__getattr__(self, name)
#    1963     if name in modules:
#    1964         return modules[name]
# -> 1965 raise AttributeError(
#    1966     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1967 )
#
# AttributeError: 'VisionTransformer' object has no attribute 'layers'

# %%
from torchinfo import summary

summary(model, input_size=(1, 3, 224, 224))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# VisionTransformer                             [1, 1000]                 768
# ├─Conv2d: 1-1                                 [1, 768, 14, 14]          590,592
# ├─Encoder: 1-2                                [1, 197, 768]             151,296
# │    └─Dropout: 2-1                           [1, 197, 768]             --
# │    └─Sequential: 2-2                        [1, 197, 768]             --
# │    │    └─EncoderBlock: 3-1                 [1, 197, 768]             7,087,872
# │    │    └─EncoderBlock: 3-2                 [1, 197, 768]             7,087,872
# │    │    └─EncoderBlock: 3-3                 [1, 197, 768]             7,087,872
# │    │    └─EncoderBlock: 3-4                 [1, 197, 768]             7,087,872
# │    │    └─EncoderBlock: 3-5                 [1, 197, 768]             7,087,872
# │    │    └─EncoderBlock: 3-6                 [1, 197, 768]             7,087,872
# │    │    └─EncoderBlock: 3-7                 [1, 197, 768]             7,087,872
# │    │    └─EncoderBlock: 3-8                 [1, 197, 768]             7,087,872
# │    │    └─EncoderBlock: 3-9                 [1, 197, 768]             7,087,872
# │    │    └─EncoderBlock: 3-10                [1, 197, 768]             7,087,872
# │    │    └─EncoderBlock: 3-11                [1, 197, 768]             7,087,872
# │    │    └─EncoderBlock: 3-12                [1, 197, 768]             7,087,872
# │    └─LayerNorm: 2-3                         [1, 197, 768]             1,536
# ├─Sequential: 1-3                             [1, 1000]                 --
# │    └─Linear: 2-4                            [1, 1000]                 769,000
# ===============================================================================================
# Total params: 86,567,656
# Trainable params: 86,567,656
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 173.23
# ===============================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 104.09
# Params size (MB): 232.27
# Estimated Total Size (MB): 336.96
# ===============================================================================================

# %%
num_ftrs = model.heads.head.in_features
model.heads.head = nn.Linear(num_ftrs, 7)

# %%
summary(model, input_size=(1, 3, 224, 224))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# VisionTransformer                             [1, 7]                    768
# ├─Conv2d: 1-1                                 [1, 768, 14, 14]          590,592
# ├─Encoder: 1-2                                [1, 197, 768]             151,296
# │    └─Dropout: 2-1                           [1, 197, 768]             --
# │    └─Sequential: 2-2                        [1, 197, 768]             --
# │    │    └─EncoderBlock: 3-1                 [1, 197, 768]             7,087,872
# │    │    └─EncoderBlock: 3-2                 [1, 197, 768]             7,087,872
# │    │    └─EncoderBlock: 3-3                 [1, 197, 768]             7,087,872
# │    │    └─EncoderBlock: 3-4                 [1, 197, 768]             7,087,872
# │    │    └─EncoderBlock: 3-5                 [1, 197, 768]             7,087,872
# │    │    └─EncoderBlock: 3-6                 [1, 197, 768]             7,087,872
# │    │    └─EncoderBlock: 3-7                 [1, 197, 768]             7,087,872
# │    │    └─EncoderBlock: 3-8                 [1, 197, 768]             7,087,872
# │    │    └─EncoderBlock: 3-9                 [1, 197, 768]             7,087,872
# │    │    └─EncoderBlock: 3-10                [1, 197, 768]             7,087,872
# │    │    └─EncoderBlock: 3-11                [1, 197, 768]             7,087,872
# │    │    └─EncoderBlock: 3-12                [1, 197, 768]             7,087,872
# │    └─LayerNorm: 2-3                         [1, 197, 768]             1,536
# ├─Sequential: 1-3                             [1, 7]                    --
# │    └─Sequential: 2-4                        [1, 7]                    --
# │    │    └─Linear: 3-13                      [1, 7]                    5,383
# ===============================================================================================
# Total params: 85,804,039
# Trainable params: 85,804,039
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 172.47
# ===============================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 104.09
# Params size (MB): 229.21
# Estimated Total Size (MB): 333.90
# ===============================================================================================

# %%
print(model.training)
# Out:
# True
